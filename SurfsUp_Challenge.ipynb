# %%
# Dependencies
import numpy as np
import pandas as pd
import dataframe_image as dfi

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

from sqlalchemy import extract

# %%
engine = create_engine("sqlite:///./Challenge_Resources/Resources/hawaii.sqlite")

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# ## D1: Determine the Summary Statistics for June

# %%
# 1. Import the sqlalchemy extract function.


# 2. Write a query that filters the Measurement table to retrieve the temperatures for the month of June. 

june_temps = session.query(Measurement).filter(extract('month', Measurement.date) == 6).all()
june_temps
# Out:
# ...
#  ...]

# %%
#  3. Convert the June temperatures to a list.

june_temps_list = [temp.tobs for temp in june_temps]
june_temps_list
# Out:
# [78.0,
#  76.0,
#  78.0,
#  76.0,
#  77.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  77.0,
#  82.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  73.0,
#  70.0,
#  76.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  78.0,
#  76.0,
#  77.0,
#  75.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  77.0,
#  77.0,
#  76.0,
#  78.0,
#  77.0,
#  76.0,
#  77.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  77.0,
#  77.0,
#  76.0,
#  75.0,
#  76.0,
#  76.0,
#  77.0,
#  76.0,
#  73.0,
#  73.0,
#  75.0,
#  77.0,
#  76.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  79.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  77.0,
#  78.0,
#  77.0,
#  76.0,
#  78.0,
#  78.0,
#  77.0,
#  78.0,
#  78.0,
#  73.0,
#  76.0,
#  77.0,
#  75.0,
#  76.0,
#  74.0,
# ...

# %%
# 4. Create a DataFrame from the list of temperatures for the month of June. 
june_temps_df = pd.DataFrame(june_temps_list, columns = ['June Temps'])
june_temps_df
# Out:
#       June Temps
# 0           78.0
# 1           76.0
# 2           78.0
# 3           76.0
# 4           77.0
# ...          ...
# 1695        79.0
# 1696        74.0
# 1697        74.0
# 1698        76.0
# 1699        75.0
#
# [1700 rows x 1 columns]

# %%
# 5. Calculate and print out the summary statistics for the June temperature DataFrame.
june_temps_sum_stats = june_temps_df.describe()
dfi.export(june_temps_sum_stats, './Challenge_Resources/june_temps_sum_stats.png')

june_temps_sum_stats
# Out:
#         June Temps
# count  1700.000000
# mean     74.944118
# std       3.257417
# min      64.000000
# 25%      73.000000
# 50%      75.000000
# 75%      77.000000
# max      85.000000

# %% [markdown]
# ## D2: Determine the Summary Statistics for December

# %%
# 6. Write a query that filters the Measurement table to retrieve the temperatures for the month of December.
dec_temps = session.query(Measurement).filter(extract('month', Measurement.date) == 12).all()
dec_temps
# Out:
# ...
#  ...]

# %%
# 7. Convert the December temperatures to a list.
dec_temps_list = [temp.tobs for temp in dec_temps]
dec_temps_list
# Out:
# [76.0,
#  74.0,
#  74.0,
#  64.0,
#  64.0,
#  67.0,
#  77.0,
#  66.0,
#  69.0,
#  68.0,
#  68.0,
#  71.0,
#  74.0,
#  67.0,
#  66.0,
#  69.0,
#  71.0,
#  70.0,
#  70.0,
#  74.0,
#  74.0,
#  71.0,
#  75.0,
#  75.0,
#  72.0,
#  69.0,
#  68.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  73.0,
#  73.0,
#  71.0,
#  73.0,
#  73.0,
#  77.0,
#  72.0,
#  71.0,
#  73.0,
#  70.0,
#  73.0,
#  69.0,
#  74.0,
#  72.0,
#  71.0,
#  72.0,
#  72.0,
#  70.0,
#  73.0,
#  73.0,
#  72.0,
#  73.0,
#  73.0,
#  72.0,
#  63.0,
#  65.0,
#  71.0,
#  76.0,
#  70.0,
#  76.0,
#  69.0,
#  69.0,
#  69.0,
#  74.0,
#  76.0,
#  74.0,
#  73.0,
#  73.0,
#  74.0,
#  73.0,
#  73.0,
#  73.0,
#  74.0,
#  74.0,
#  71.0,
#  73.0,
#  72.0,
#  64.0,
#  66.0,
#  73.0,
#  72.0,
#  65.0,
#  64.0,
#  69.0,
#  68.0,
#  77.0,
#  71.0,
#  71.0,
#  69.0,
#  68.0,
#  68.0,
#  69.0,
#  70.0,
#  72.0,
#  76.0,
#  75.0,
#  69.0,
#  71.0,
#  71.0,
#  71.0,
#  68.0,
#  65.0,
#  70.0,
#  69.0,
#  69.0,
#  71.0,
#  67.0,
#  73.0,
#  74.0,
#  73.0,
# ...

# %%
# 8. Create a DataFrame from the list of temperatures for the month of December. 
dec_temps_df = pd.DataFrame(dec_temps_list, columns = ['Dec Temps'])
dec_temps_df
# Out:
#       Dec Temps
# 0          76.0
# 1          74.0
# 2          74.0
# 3          64.0
# 4          64.0
# ...         ...
# 1512       71.0
# 1513       71.0
# 1514       69.0
# 1515       65.0
# 1516       65.0
#
# [1517 rows x 1 columns]

# %%
# 9. Calculate and print out the summary statistics for the Decemeber temperature DataFrame.
dec_temps_sum_stats = dec_temps_df.describe()
dfi.export(dec_temps_sum_stats, './Challenge_Resources/dec_temps_sum_stats.png')

dec_temps_sum_stats
# Out:
#          Dec Temps
# count  1517.000000
# mean     71.041529
# std       3.745920
# min      56.000000
# 25%      69.000000
# 50%      71.000000
# 75%      74.000000
# max      83.000000
